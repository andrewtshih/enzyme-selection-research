# %%
import pandas as pd

# %%
def create_table(file_name):
    metal_tbl = pd.read_csv(file_name)
    return metal_tbl

# %%
def find_common_aa_seq(df):
    return df['Amino acids or nucleotide residues names'].value_counts()

# %%
def find_common_aa(df):
    aa_list = list(df['Amino acids or nucleotide residues names'])
    
    split_aa_list = []
    for aa_seq in aa_list:
        split_aa_list.append(aa_seq.split('.'))
        
    no_empty = []
    for i in sep_aa_list:
        no_empty.append(i[:-1])
        
    one_list = []
    for j in no_empty:
        one_list += j
        
    ind_aa_counts = pd.Series(one_list).value_counts()
        
    return ind_aa_counts

# %%
def final(file_name):
    metal_tbl = create_table(file_name)
    aa_seq_ser = find_common_aa_seq(metal_tbl)
    aa_list = find_common_aa(metal_tbl)
    return aa_seq_ser, aa_list

# %%
final('table.csv')
# Out:
# (HIS.                62
#  ASP.                17
#  GLU.                 9
#  ASN.ASP.LEU.PHE.     8
#  GLU.HIS.             4
#  ASN.GLU.NAG.         3
#  ARG.ASP.HIS.         3
#  ASP.GLU.             3
#  DT.ILE.LEU.          2
#  ASP.GLU.LEU.VAL.     2
#  ASP.GLY.             2
#  ASP.LEU.             2
#  GLN.GLY.             2
#  TRP.                 2
#  ASN.ASP.G46.         1
#  ASP.SER.THR.         1
#  SER.                 1
#  ASN.SER.THR.         1
#  CYS.                 1
#  ASN.                 1
#  Name: Amino acids or nucleotide residues names, dtype: int64,
#  HIS    69
#  ASP    39
#  GLU    21
#  ASN    14
#  LEU    14
#  PHE     8
#  GLY     4
#  SER     3
#  ARG     3
#  NAG     3
#  VAL     2
#  GLN     2
#  TRP     2
#  ILE     2
#  DT      2
#  THR     2
#  CYS     1
#  G46     1
#  dtype: int64)
